# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

# %%
clicks = pd.read_csv("data/clicks.csv.gzip", dtype = {"advertiser_id": np.int8, "action_id": np.float16, "source_id": np.int8, "wifi_connection": bool, "carrier_id": np.float16, "brand": np.float16, "touchX": np.float16, "touchY": np.float16})
del clicks['action_id']
clicks.head(10)
# Out:
#    advertiser_id  source_id                   created         country_code  \
# 0              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 1              0          0  2019-03-08T10:24:30.641Z  6333597102633388268
# 2              0          0  2019-03-08T15:24:16.069Z  6333597102633388268
# 3              2          3  2019-03-06T03:08:51.543Z  6333597102633388268
# 4              2          3  2019-03-06T03:32:55.570Z  6333597102633388268
# 5              5          4  2019-03-07T18:02:25.833Z  6333597102633388268
# 6              3          1  2019-03-12T15:17:04.453Z  6333597102633388268
# 7              1          2  2019-03-06T19:15:47.249Z  6333597102633388268
# 8              3          0  2019-03-07T23:11:01.934Z  6333597102633388268
# 9              3          1  2019-03-07T23:06:30.642Z  6333597102633388268
#
#    latitude  longitude  wifi_connection  carrier_id  \
# 0  1.205689   1.070234            False         1.0
# 1  1.218924   1.071209            False         4.0
# 2  1.205689   1.070234            False         6.0
# 3  1.205689   1.070234            False        45.0
# 4  1.205689   1.070234            False        45.0
# 5  1.209638   1.064208            False        27.0
# 6  1.209638   1.064208            False        27.0
# 7  1.205393   1.077238            False         NaN
# 8  1.205058   1.077332            False        19.0
# 9  1.205689   1.070234            False        18.0
#
#                           trans_id      os_minor  agent_device      os_major  \
# 0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18           NaN  3.072849e+18
# 1  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM  3.025219e+18           NaN  1.774085e+18
# 2  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU  5.975656e+18           NaN  3.072849e+18
# 3  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM  6.768137e+18           NaN  3.072849e+18
# 4  X5XTOcYQovkl6yadYdAD7xioVGU9jiY  6.768137e+18           NaN  3.072849e+18
# 5  dhc5iaRvlrI9OgkXDWnMRrAY47xWozY  3.025219e+18           NaN  1.774085e+18
# 6  cOm-_s2_6NkoDWYNu_QaMk-v4sf34h4  3.378640e+18  3.032809e+17  4.566454e+18
# 7  MbDYk_2nKmKtOQgAIRx-aDJ66VIGsrE           NaN           NaN           NaN
# 8  1wsFgNNvk6PT1QSSIdmmwmqp0E3k7io  3.025219e+18           NaN  1.774085e+18
# 9  ZLZz1XHsA5Xkuq_TXNfT49j_H4mfTwg  3.378640e+18           NaN  4.566454e+18
#
#            specs_brand  brand  timeToClick    touchX    touchY  \
# 0  2733035977666442898    NaN        1.563  0.904785  0.078003
# 1   392184377613098015    NaN          NaN       NaN       NaN
# 2   392184377613098015    NaN          NaN  0.945801  0.472900
# 3  2733035977666442898    NaN       19.013  0.035004  0.430908
# 4  2733035977666442898    NaN       28.110  0.053986  0.423096
# 5   392184377613098015    1.0          NaN  0.605957  0.458984
# 6  2733035977666442898    1.0          NaN       NaN       NaN
# 7  8930605132947907029    NaN          NaN       NaN       NaN
# 8   392184377613098015    NaN        3.129  0.889160  0.977051
# 9  2733035977666442898    1.0        1.707  0.466064  0.984863
#
#               ref_type             ref_hash
# 0  1891515180541284343  1904083516767779093
# 1  1891515180541284343  3086509764961796666
# 2  1891515180541284343  6958163894863846647
# 3  1891515180541284343  4368617728156436525
# 4  1891515180541284343  4368617728156436525
# 5  1891515180541284343  7925959310979071406
# 6  1891515180541284343  1709687652740629839
# 7  1891515180541284343  2127839020694198991
# 8  1891515180541284343  5073558237453939035
# 9  1891515180541284343    70349377423764005

# %%
import reverse_geocoder as rg
def get_Country(coord):
        a=rg.search(coord)
        return a[0]['cc']
def get_City(coord):
        a=rg.search(coord)
        return a[0]['name']

# %%
coordinates = (51.5214588,-0.1729636),(9.936033, 76.259952),(37.38605,-122.08385)
rg.search(coordinates)

# %%
get_City((-1.205689 ,1.070234))

# %%
get_Country((-1.205689 ,1.070234))

# %%
#### explorar la posibilidad de hacer un mapa con las ubicaciones

# %%
#son datos de un solo pais
sns.countplot(x='country_code', data=clicks)

# %%
sns.countplot(x='advertiser_id', data=clicks)

# %%
clicks['created']=pd.to_datetime(clicks['created'])

# %%
clicks['año'] = pd.DatetimeIndex(clicks['created']).year
clicks['mes'] =clicks['created'].dt.month
clicks['día'] = clicks['created'].dt.day
clicks['hora'] = clicks['created'].dt.hour
clicks['minuto'] = clicks['created'].dt.minute
clicks['diaSemana'] = clicks['created'].dt.weekday_name
clicks.head()

# %%
grupo_clicks_por_dia=clicks.groupby(['advertiser_id','diaSemana'])['diaSemana'].count().sort_values(ascending=False).rename("Totalclicks").reset_index()
#grupo_clicks_por_dia=grupo_clicks_por_dia.head(50)

# %%
ax = sns.barplot(x='diaSemana', y='Totalclicks', data=grupo_clicks_por_dia)
ax.set_title('Clicslltotales según dia de la semana dede 5/3/19 al 13/3/19')
ax.figure.set_size_inches(16, 4)

# %%
vis9 = sns.swarmplot(x="Totalclicks", y="diaSemana", hue="advertiser_id", data=grupo_clicks_por_dia)
vis9.legend_.remove()
plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # Analizo installs

# %%
inst = pd.read_csv("data/installs.csv", dtype = {"application_id": np.int16, "click_hash": np.float16})

# %%
inst.memory_usage(deep=True).sum()
# Out:
# 1495715

# %%
del inst['event_uuid']
del inst['click_hash']
del inst['trans_id']
inst['created']=pd.to_datetime(inst['created'])
inst['wifi']=inst['wifi'].astype('bool')
inst['session_user_agent']=inst['session_user_agent'].dropna()
inst['session_user_agent']=inst['session_user_agent'].astype('category')

inst['user_agent']=inst['user_agent'].astype('category')
inst['device_countrycode']=inst['device_countrycode'].astype('category')
inst['device_brand']=inst['device_brand'].astype('category')
inst['device_language']=inst['device_language'].astype('category')
inst['kind']=inst['kind'].astype('category')

# %%
inst.memory_usage(deep=True).sum()
# Out:
# 235100

# %%
inst['año'] = pd.DatetimeIndex(inst['created']).year
inst['mes'] =inst['created'].dt.month
inst['día'] = inst['created'].dt.day
inst['hora'] = inst['created'].dt.hour
inst['minuto'] = inst['created'].dt.minute
inst['diaSemana'] = inst['created'].dt.weekday_name
inst.head()
# Out:
#                   created  application_id             ref_type  \
# 0 2019-03-13 01:43:33.445               0  1891515180541284343
# 1 2019-03-13 04:58:35.078               0  1891515180541284343
# 2 2019-03-13 04:20:57.666               0  1891515180541284343
# 3 2019-03-13 04:20:57.698               0  1891515180541284343
# 4 2019-03-10 22:24:56.684               0  1891515180541284343
#
#               ref_hash  attributed  implicit   device_countrycode  \
# 0  8464844987297247076       False     False  6333597102633388268
# 1  3250564871270161533       False     False  6333597102633388268
# 2  7953318831018100268       False      True  6333597102633388268
# 3  7953318831018100268       False     False  6333597102633388268
# 4  8355110941557237501       False      True  6333597102633388268
#
#    device_brand  device_model                 session_user_agent  ...  kind  \
# 0  3.083059e+17  4.445252e+18                                NaN  ...   NaN
# 1  3.083059e+17  4.445252e+18                                NaN  ...   NaN
# 2  5.137992e+17  6.026543e+18  HasOffers Mobile AppTracking v1.0  ...  Open
# 3  5.137992e+17  6.026543e+18                                NaN  ...   NaN
# 4  1.083369e+18  7.876612e+18  HasOffers Mobile AppTracking v1.0  ...  Open
#
#    wifi           ip_address  device_language   año  mes  día  hora  minuto  \
# 0  True  5529284367937637301              NaN  2019    3   13     1      43
# 1  True  6098022721363533304              NaN  2019    3   13     4      58
# 2  True  4636407223847323867     3.301378e+18  2019    3   13     4      20
# 3  True  4636407223847323867              NaN  2019    3   13     4      20
# 4  True   685400811232710215     3.301378e+18  2019    3   10    22      24
#
#    diaSemana
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4     Sunday
#
# [5 rows x 21 columns]

# %%
inst['created'].describe()
# Out:
# count                           3412
# unique                          3412
# top       2019-03-09 04:34:41.291000
# freq                               1
# first     2019-03-05 00:00:38.219000
# last      2019-03-13 23:54:00.526000
# Name: created, dtype: object

# %%
ax=sns.countplot(x='wifi', data=inst)
ax.set_title('Instalaciones totales en función del si estaba conectada a una red WIFI según dia de la semana dede 5/3/19 al 13/3/19')
ax.figure.set_size_inches(16, 4)

# %%
inst['attributed'].describe()
# Out:
# count      3412
# unique        1
# top       False
# freq       3412
# Name: attributed, dtype: object

# %%
grupo_inst_por_dia=inst.groupby(['application_id','diaSemana'])['application_id'].count().sort_values(ascending=False).rename("Total instalaciones").reset_index()
grupo_inst_por_dia.head(20)
# Out:
#     application_id  diaSemana  Total instalaciones
# 0                7    Tuesday                  222
# 1                7  Wednesday                  211
# 2                9  Wednesday                  190
# 3                9    Tuesday                  175
# 4                7   Thursday                  122
# 5                7     Friday                  108
# 6                9   Thursday                  100
# 7               10    Tuesday                   99
# 8                7     Monday                   97
# 9                7   Saturday                   97
# 10               7     Sunday                   90
# 11              16    Tuesday                   85
# 12               9     Friday                   85
# 13              10  Wednesday                   83
# 14              16  Wednesday                   77
# 15               9     Monday                   74
# 16               8    Tuesday                   73
# 17               8  Wednesday                   67
# 18               9     Sunday                   54
# 19               9   Saturday                   53

# %%
# Conversiones por dia de smeana
ax = sns.barplot(x='diaSemana', y='Total instalaciones', data=grupo_inst_por_dia)
ax.set_title('Instalaciones totales según dia de la semana dede 5/3/19 al 13/3/19')
ax.figure.set_size_inches(16, 4)

# %%
vis9 = sns.swarmplot(x="Total instalaciones", y="diaSemana", hue="application_id", data=grupo_inst_por_dia)
vis9.legend_.remove()
plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.show()data:image/png;base64,...

# %%
grupo_inst_por_hora=inst.groupby(['application_id','diaSemana','hora'])['application_id'].count().sort_values(ascending=False).rename("Cantidad instalaciones").reset_index()
#grupo_inst_por_hora=grupo_inst_por_hora.head(100) 
grupo_inst_por_hora.head()
# Out:
#    application_id  diaSemana  hora  Cantidad instalaciones
# 0               7  Wednesday    21                      18
# 1               9    Tuesday    14                      18
# 2               9    Tuesday    23                      17
# 3               7    Tuesday     1                      17
# 4               7  Wednesday    15                      17

# %%
vis7 = sns.lmplot(data = grupo_inst_por_hora, x = "hora", y ="Cantidad instalaciones",fit_reg=False, hue = "application_id",size = 6, aspect=1.5, scatter_kws = {'s':200}, )
# Out:
# /home/sol/.local/lib/python3.6/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
vis5 = sns.boxplot(data = grupo_inst_por_dia, y = "Total instalaciones", x = "diaSemana")
fig = vis5.get_figure()

# %% [markdown]
# # ¿Podemos mergear los dataframes installs y clicks?

# %% [markdown]
# Lo que se busca con el merge es verificar si un usuario tiende a instalar la aplicación luego de ver la publicidad, para eso se busca comparar las fechas de click y las fechas de instalación, y ver la diferencia entre ambas. Para analizar esto correctamente hay que asegurarse de estar analizando sobre exactamente el mismo dispositivo

# %%
clicks.dtypes
# Out:
# advertiser_id         int8
# source_id             int8
# created             object
# country_code         int64
# latitude           float64
# longitude          float64
# wifi_connection       bool
# carrier_id         float16
# trans_id            object
# os_minor           float64
# agent_device       float64
# os_major           float64
# specs_brand          int64
# brand              float16
# timeToClick        float64
# touchX             float16
# touchY             float16
# ref_type             int64
# ref_hash             int64
# dtype: object

# %% [markdown]
# Asumiendo que la columna application_id del dataframe install y la columna advertiser_id del dataframe clicks refieren a la misma aplicación, se mergean los dataframes de installs y clicks. Luego, filtro el dataframe mergeado para poder asegurar el click y el install pertenecen al mismo dispositivo, sin embargo no se encuentra información suficiente para asegurarlo.

# %%
installs = inst
merged = pd.merge(clicks, installs, left_on = "advertiser_id", right_on = "application_id", how = "inner")
merged = merged.loc[merged['country_code'] == merged['device_countrycode']]
merged.head()
# Out:
#    advertiser_id  source_id                 created_x         country_code  \
# 0              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 1              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 2              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 3              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 4              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
#
#    latitude  longitude  wifi_connection  carrier_id  \
# 0  1.205689   1.070234            False         1.0
# 1  1.205689   1.070234            False         1.0
# 2  1.205689   1.070234            False         1.0
# 3  1.205689   1.070234            False         1.0
# 4  1.205689   1.070234            False         1.0
#
#                           trans_id      os_minor  ...  kind  wifi  \
# 0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...   NaN  True
# 1  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...   NaN  True
# 2  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...   NaN  True
# 3  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...  open  True
# 4  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...   NaN  True
#
#             ip_address  device_language   año  mes  día  hora  minuto  \
# 0  5997848429649592955     9.028383e+18  2019    3   13     8      29
# 1  6500828119610424253     9.028383e+18  2019    3   13     4      30
# 2   519141635435520031     9.028383e+18  2019    3   13     0      26
# 3  8219558276376618700     9.028383e+18  2019    3   13    11      36
# 4  5625480666756000613     9.028383e+18  2019    3   13    13      15
#
#    diaSemana
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday
#
# [5 rows x 40 columns]

# %%
merged['created_x'] = merged['created_x'].astype(str)

merged['fecha_x'] = merged['created_x'].str[:10] + ' ' + merged['created_x'].str[11:23]
merged.head()
# Out:
#    advertiser_id  source_id                 created_x         country_code  \
# 0              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 1              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 2              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 3              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
# 4              2          4  2019-03-06T22:42:12.755Z  6333597102633388268
#
#    latitude  longitude  wifi_connection  carrier_id  \
# 0  1.205689   1.070234            False         1.0
# 1  1.205689   1.070234            False         1.0
# 2  1.205689   1.070234            False         1.0
# 3  1.205689   1.070234            False         1.0
# 4  1.205689   1.070234            False         1.0
#
#                           trans_id      os_minor  ...  wifi  \
# 0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...  True
# 1  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...  True
# 2  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...  True
# 3  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...  True
# 4  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18  ...  True
#
#             ip_address  device_language   año  mes  día  hora  minuto  \
# 0  5997848429649592955     9.028383e+18  2019    3   13     8      29
# 1  6500828119610424253     9.028383e+18  2019    3   13     4      30
# 2   519141635435520031     9.028383e+18  2019    3   13     0      26
# 3  8219558276376618700     9.028383e+18  2019    3   13    11      36
# 4  5625480666756000613     9.028383e+18  2019    3   13    13      15
#
#    diaSemana                  fecha_x
# 0  Wednesday  2019-03-06 22:42:12.755
# 1  Wednesday  2019-03-06 22:42:12.755
# 2  Wednesday  2019-03-06 22:42:12.755
# 3  Wednesday  2019-03-06 22:42:12.755
# 4  Wednesday  2019-03-06 22:42:12.755
#
# [5 rows x 41 columns]

# %% [markdown]
# Ahora busco comparar las fechas de instalación y fechas de clicks para cada id de advertiser (asumiendo que es la equivalente a la id de la aplicación), para ello recupero la fecha de cada click e instalación con la mayor precisión posible. Con esto se busca verificar si hay aplicaciones cuya instalación se realizó al poco tiempo de haber hecho click en la publicidad de la misma

# %%
merged['fecha_x'] = pd.to_datetime(merged['fecha_x'])
merged['created_y'] = merged['created_y'].astype(str)

merged['fecha_y'] = merged['created_y'].str[:10] + ' ' + merged['created_y'].str[11:23]
merged.head()

merged['fecha_y'] = pd.to_datetime(merged['fecha_y'])

merged=merged.rename(columns = {'fecha_x':'fecha click', 'fecha_y':'fecha install'})

mergedFechas = merged[['advertiser_id','fecha click','fecha install']]
mergedFechas.head()
# Out:
#    advertiser_id             fecha click           fecha install
# 0              2 2019-03-06 22:42:12.755 2019-03-13 08:29:31.875
# 1              2 2019-03-06 22:42:12.755 2019-03-13 04:30:00.812
# 2              2 2019-03-06 22:42:12.755 2019-03-13 00:26:32.561
# 3              2 2019-03-06 22:42:12.755 2019-03-13 11:36:30.025
# 4              2 2019-03-06 22:42:12.755 2019-03-13 13:15:14.566

# %% [markdown]
# Se crea una columna con la diferencia de tiempo entre la fecha de click y la fecha de instalación para cada advertiser_id, se entende que si una persona abre una publicidad y esta la convence de instalarla, la diferencia de tiempo entre instalación y click no debería ser muy grande.

# %%
mergedFechas['diferencia de tiempo'] = mergedFechas['fecha install'] - mergedFechas['fecha click']
mergedFechas.head()
# Out:
# /home/sol/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    advertiser_id             fecha click           fecha install  \
# 0              2 2019-03-06 22:42:12.755 2019-03-13 08:29:31.875
# 1              2 2019-03-06 22:42:12.755 2019-03-13 04:30:00.812
# 2              2 2019-03-06 22:42:12.755 2019-03-13 00:26:32.561
# 3              2 2019-03-06 22:42:12.755 2019-03-13 11:36:30.025
# 4              2 2019-03-06 22:42:12.755 2019-03-13 13:15:14.566
#
#     diferencia de tiempo
# 0 6 days 09:47:19.120000
# 1 6 days 05:47:48.057000
# 2 6 days 01:44:19.806000
# 3 6 days 12:54:17.270000
# 4 6 days 14:33:01.811000

# %% [markdown]
# Se entiende que la diferencia de tiempo no debería ser mayor a 20 minutos

# %%
mergedFechasAppsInstaladas = mergedFechas\
        .loc[mergedFechas['diferencia de tiempo'] >= pd.Timedelta(0,'D')]\
        .loc[mergedFechas['diferencia de tiempo'] < pd.Timedelta(20,'m')]        
        #.loc[mergedFechas['diferencia de tiempo'] = pd.Timedelta(0,'h')]\
        #.loc[mergedFechas['diferencia de tiempo'] = pd.Timedelta(0,'m')]
mergedFechasAppsInstaladas.sort_values(by = 'diferencia de tiempo', ascending = False)
# Out:
#       advertiser_id             fecha click           fecha install  \
# 679               2 2019-03-05 22:58:38.072 2019-03-05 23:18:34.149
# 842               2 2019-03-05 19:57:05.377 2019-03-05 20:08:23.242
# 1368              2 2019-03-05 18:09:34.110 2019-03-05 18:20:07.931
# 1714              2 2019-03-05 19:11:45.452 2019-03-05 19:13:07.249
# 1713              2 2019-03-05 19:11:45.452 2019-03-05 19:12:35.860
#
#      diferencia de tiempo
# 679       00:19:56.077000
# 842       00:11:17.865000
# 1368      00:10:33.821000
# 1714      00:01:21.797000
# 1713      00:00:50.408000

# %% [markdown]
# No se consigue una cantidad suficiente de datos con este análisis para poder verificar si los usuarios realmente instalan las aplicaciones luego de haber dado click en su respectiva publicidad, además para los datos recibidos no puede asegurarse que el click y la instalación se hayan dado en el mismo dispositivo
