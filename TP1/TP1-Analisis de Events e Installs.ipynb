# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.gridspec import GridSpec

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
evts = pd.read_csv("data/events.csv", dtype = {"event_id": np.int16, "application_id": np.int16}, usecols = ["date", "application_id", "attributed", "event_uuid", "connection_type", "device_language"])
inst = pd.read_csv("data/installs.csv", dtype = {"application_id": np.int16, "click_hash": np.float16})
#clks = pd.read_csv("data/clicks.csv.gzip", dtype = {"advertiser_id": np.int8, "action_id": np.float16, "source_id": np.int8, "wifi_connection": bool, "carrier_id": np.float16, "brand": np.float16, "touchX": np.float16, "touchY": np.float16})
# Out:
# /home/sol/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Intento encontrar algo entre los events y las instalaciones

# %%
evts.columns
# Out:
# Index(['date', 'application_id', 'attributed', 'event_uuid', 'connection_type',
#        'device_language'],
#       dtype='object')

# %%
inst.columns
# Out:
# Index(['created', 'application_id', 'ref_type', 'ref_hash', 'click_hash',
#        'attributed', 'implicit', 'device_countrycode', 'device_brand',
#        'device_model', 'session_user_agent', 'user_agent', 'event_uuid',
#        'kind', 'wifi', 'trans_id', 'ip_address', 'device_language'],
#       dtype='object')

# %% [markdown]
# ## ¿Cuántas fechas hay?

# %%
installs = inst
installs['date'] = pd.to_datetime(installs['created'], format='%Y%m%d %H:%M:%S.%f').dt.date
installs['hour'] = pd.to_datetime(installs['created'], format='%Y%m%d %H:%M:%S.%f').dt.hour
cantidadPorDate = installs['date'].value_counts()
cantidadPorDate

grafDate = cantidadPorDate.plot(kind = 'bar', figsize = (14,4))

# %% [markdown]
# ## ¿Influye la hora del día en la cantidad de instalaciones?

# %%
cantidadPorHour = inst['hour'].value_counts()

plt.figure(figsize=(15,5))
sns.set_style('darkgrid')
plotH = sns.lineplot(x = cantidadPorHour.index, y = cantidadPorHour.values)
plotH.set_title("Cantidad de installs en funcion del horario del dia", fontsize = 25)
plotH.set_xlabel("Hora en formato 0 a 24", fontsize = 15)
plotH.set_ylabel("Cantidad de installs", fontsize = 15)
# Out:
# Text(0,0.5,'Cantidad de installs')

# %% [markdown]
# Los horarios con menos installs son los horarios en los que la gente se suele levantar para estudiar. Los horarios las horas entre las 12 y las 14 se atribuyen al horaro del almuerzo. Llama la atención

# %% [markdown]
# ## ¿Cuál es la brand con más y menos instalaciones?

# %%
cantidadPorBrands = installs['device_brand'].value_counts()

#Primero veo las marcas con más instalaciones

grafBrands = cantidadPorBrands.nlargest(10).plot(kind = 'bar', figsize = (14,4))

# %%
#Ahora veo las que tienen menos

grafBrands = cantidadPorBrands.nsmallest(10).plot(kind = 'bar', figsize = (14,4))

# %% [markdown]
# ## ¿Cuál es el modelo con mayor y menor cantidad de instalaciones?

# %%
cantidadPorModel = installs['device_model'].value_counts()

#Veo el que tiene más

grafModel = cantidadPorModel.nlargest(20).plot(kind = 'bar', figsize = (14,4))

# %% [markdown]
# Se ve una amplia diferencia entre el modelo de código 2.331947e+18 y el 6.882415e+18, siendo el primero con más del doble de instalaciones que el segundo.
#
# Ahora veo el modelo con menos instalaciones

# %%
grafModel = cantidadPorModel.nsmallest(20).plot(kind = 'bar', figsize = (14,4))

# %% [markdown]
# No se pueden sacar conclusiones interesantes de esta pregunta, tanto para el mayor como para el menor, ya que no se tienen la cantidad de celulares con este modelo, entonces no se puede saber si el modelo con mayor cantidad de instalaciones es simplemente el modelo más usado por los usuarios

# %% [markdown]
# ## ¿Como se comportan las apps en relación a la cantidad de instalaciones?

# %%
cantidadPorAppId = installs['application_id'].value_counts()

#Apps más instaladas

grafAppId = cantidadPorAppId.nlargest(15).plot(kind = 'bar', figsize = (14,4))

# %%
#Las menos instaladas

grafAppId = cantidadPorAppId.nsmallest(15).plot(kind = 'bar', figsize = (14,4))

# %% [markdown]
# ## ¿Cuántas instalaciones fueron hechas por dispositivos que no habían instalado nada previamente?

# %%
cantidadPorImplicit = installs['implicit'].value_counts()

grafImplicit = cantidadPorImplicit.plot(kind = 'bar', figsize = (14,4))

# %% [markdown]
# ## Veo como se comportan los eventos según su tipo de conexión

# %%
#Catidad de eventos según el tipo de conexión
conexiones = evts['connection_type'].value_counts() 
conexiones
# Out:
# Cable/DSL    331948
# Cellular     280511
# Corporate         4
# Name: connection_type, dtype: int64

# %%
#Como el tipo Corporate tiene tan solo 4 apariciones y los otros más de 2 millones,
#sucede que tiene un valor despreciable frente a los otros dos, 
#por lo que podría solo tomar en cuenta los tipos de conexión predominantes.
plt.figure(figsize=(8,5)) 
conexiones = conexiones.drop(labels = ['Corporate'], axis = 0)
grf2 = sns.barplot(x = conexiones.index, y = conexiones.values, orient = 'v', palette = 'Reds') 
grf2.set_title("Tipos de conexiones predominantes entre los eventos", fontsize = 20)
grf2.set_ylabel("Cantidad de conexiones", fontsize = 15)
grf2.set_xlabel("Tipo de conexión", fontsize = 15)
# Out:
# Text(0.5,0,'Tipo de conexión')

# %% [markdown]
# ## ¿Qué hay entre el campo "application_id" del set "events" y el set "installs"?

# %%
apps_populares_evts = evts["application_id"].value_counts().nlargest(10)
apps_populares_evts
# Out:
# 66     325696
# 64     259084
# 145    252431
# 63     181555
# 103    137513
# 57     134498
# 121    123711
# 212    108489
# 113     82962
# 39      76448
# Name: application_id, dtype: int64

# %%
plt.figure(figsize=(10,8)) 
sns.set_style('darkgrid') 
grf3 = sns.barplot(x = apps_populares_evts.values, y = apps_populares_evts.index, orient = 'h') 
grf3.set_title("Cantidad de de eventos según el identificador de aplicación", fontsize = 25) 
grf3.set_ylabel("Identificador de aplicación", fontsize = 15) 
grf3.set_xlabel("Cantidad de eventos", fontsize = 15)
# Out:
# Text(0.5,0,'Cantidad de eventos')

# %%
apps_populares_inst = inst["application_id"].value_counts().nlargest(10)
apps_populares_inst
# Out:
# 7     947
# 9     731
# 10    389
# 16    362
# 8     328
# 2     174
# 29     97
# 20     95
# 6      35
# 1      34
# Name: application_id, dtype: int64

# %%
plt.figure(figsize=(10,8)) 
sns.set_style('darkgrid') 
grf3 = sns.barplot(x = apps_populares_inst.values, y = apps_populares_inst.index, orient = 'h', palette = 'Dark2') 
grf3.set_title("Cantidad de de instalaciones según el identificador de aplicación", fontsize = 25) 
grf3.set_ylabel("Identificador de aplicación", fontsize = 15) 
grf3.set_xlabel("Cantidad de instalaciones", fontsize = 15)
# Out:
# Text(0.5,0,'Cantidad de instalaciones')

# %% [markdown]
# ## Vemos que sucede con los eventos y las instalaciones atribuidas a Jammp

# %%
#Eventos atribuidos a jummp 
eventos_atrib_app = evts['attributed'].value_counts()
eventos_atrib_app
# Out:
# False    2489324
# True        5099
# Name: attributed, dtype: int64

# %% [markdown]
# Notamos que del total de eventos son muy pocos los atribuidos a Jammp.
#
# Veamos ahora que encontramos en las instalaciones.

# %%
#instalaciones atribuidas a Jammp
inst['attributed'].value_counts()
# Out:
# False    3412
# Name: attributed, dtype: int64

# %%
inst['created'].head()
# Out:
# 0    2019-03-13 01:43:33.445
# 1    2019-03-13 04:58:35.078
# 2    2019-03-13 04:20:57.666
# 3    2019-03-13 04:20:57.698
# 4    2019-03-10 22:24:56.684
# Name: created, dtype: object

# %% [markdown]
# De las instalaciones directamente ninguna es atribuida a Jammp.

# %% [markdown]
# ## Quiero ver a qué tipo de instalación están relacionados los session_user_agent qué realizaron más instalaciones

# %%
#cuento los tipos de installación posibles y filtro los que tienen menos de 5 instalaciones
inst_kind = inst['kind'].value_counts().nlargest(10)
inst_kind
# Out:
# af_app_opened                 428
# app_open                      212
# EVENT_Homepage                 70
# open                           36
# EVENT_OPEN_APP                 33
# Open                           22
# login_success                  17
# account_summary_first_step     13
# EVENT_LISTINGVIEW_FLIGHT        6
# EVENT_HOMEPAGE                  6
# Name: kind, dtype: int64

# %%
#veo cuantos session_user_agents hay filtrando los que tengan menos de 5 intallaciones
session_inst = inst['session_user_agent'].value_counts().nlargest(4)
session_inst
# Out:
# http-kit/2.0                                                                                                                                 1729
# adjust.com                                                                                                                                   1592
# HasOffers Mobile AppTracking v1.0                                                                                                              22
# Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.0 Mobile/15E148 Safari/604.1      10
# Name: session_user_agent, dtype: int64

# %%
session_and_kind = inst.groupby(['kind','session_user_agent']).agg({'created': 'count'})
session_and_kind
# Out:
#                                                               created
# kind                       session_user_agent
# EVENT_HOMEPAGE             adjust.com                               6
# EVENT_Homepage             adjust.com                              70
# EVENT_LISTINGVIEW_FLIGHT   adjust.com                               6
# EVENT_OPEN_APP             adjust.com                              33
# EVENT_PROMO                adjust.com                               1
# Open                       HasOffers Mobile AppTracking v1.0       22
# account_summary_first_step http-kit/2.0                            13
# af_app_opened              http-kit/2.0                           428
# af_list_view               http-kit/2.0                             1
# app_open                   adjust.com                             212
# deeplink                   adjust.com                               5
# install                    adjust.com                               1
# journey drop off           adjust.com                               1
# journey first drop off     adjust.com                               2
# journey reserved           adjust.com                               1
# login_success              http-kit/2.0                            17
# open                       http-kit/2.0                            36
# payment method add         adjust.com                               3
# reattribution              adjust.com                               4
# registration               http-kit/2.0                             3

# %% [markdown]
# Veamos que pasa con los que no se conoce el tipo:

# %%
# Relleno los Nan con un string 'desconocido'
inst_kind = inst.filter(items = ['created', 'kind', 'session_user_agent']).fillna('desconocido')
inst_kind.groupby(['kind','session_user_agent']).agg({'created': 'count'})
# Out:
#                                                                                created
# kind                       session_user_agent
# EVENT_HOMEPAGE             adjust.com                                                6
# EVENT_Homepage             adjust.com                                               70
# EVENT_LISTINGVIEW_FLIGHT   adjust.com                                                6
# EVENT_OPEN_APP             adjust.com                                               33
# EVENT_PROMO                adjust.com                                                1
# Open                       HasOffers Mobile AppTracking v1.0                        22
# account_summary_first_step http-kit/2.0                                             13
# af_app_opened              http-kit/2.0                                            428
# af_list_view               http-kit/2.0                                              1
# app_open                   adjust.com                                              212
# deeplink                   adjust.com                                                5
# desconocido                Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...        1
#                            Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...        1
#                            Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...        1
#                            Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...        1
#                            Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...        3
#                            Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...        1
#                            Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...        1
#                            Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...        2
#                            Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...       10
#                            adjust.com                                             1247
#                            desconocido                                              48
#                            http-kit/2.0                                           1231
# install                    adjust.com                                                1
# journey drop off           adjust.com                                                1
# journey first drop off     adjust.com                                                2
# journey reserved           adjust.com                                                1
# login_success              http-kit/2.0                                             17
# open                       http-kit/2.0                                             36
# payment method add         adjust.com                                                3
# reattribution              adjust.com                                                4
# registration               http-kit/2.0                                              3

# %% [markdown]
# Modifico los nombres de los session_user_agent para que sean más facil de leer. Como puede verse los session_user_agent que corresponden a Mozilla son muchos pero tiene muy pocas installs, así que los vamos a agrupar

# %%
def perteneceAMozilla(x):
    return 'Mozilla' in x

inst_kind['sessionUserAgent'] = inst_kind['session_user_agent'].apply(lambda x : 'Mozilla' if perteneceAMozilla(x) else x)
inst_kind.head(10)
# Out:
#                    created         kind                 session_user_agent  \
# 0  2019-03-13 01:43:33.445  desconocido                        desconocido
# 1  2019-03-13 04:58:35.078  desconocido                        desconocido
# 2  2019-03-13 04:20:57.666         Open  HasOffers Mobile AppTracking v1.0
# 3  2019-03-13 04:20:57.698  desconocido                        desconocido
# 4  2019-03-10 22:24:56.684         Open  HasOffers Mobile AppTracking v1.0
# 5  2019-03-10 22:24:57.545  desconocido                        desconocido
# 6  2019-03-11 03:47:22.802         Open  HasOffers Mobile AppTracking v1.0
# 7  2019-03-11 21:21:05.986  desconocido                        desconocido
# 8  2019-03-11 21:21:05.855         Open  HasOffers Mobile AppTracking v1.0
# 9  2019-03-13 08:29:31.875  desconocido                       http-kit/2.0
#
#                     sessionUserAgent
# 0                        desconocido
# 1                        desconocido
# 2  HasOffers Mobile AppTracking v1.0
# 3                        desconocido
# 4  HasOffers Mobile AppTracking v1.0
# 5                        desconocido
# 6  HasOffers Mobile AppTracking v1.0
# 7                        desconocido
# 8  HasOffers Mobile AppTracking v1.0
# 9                       http-kit/2.0

# %%
count_session_kind = inst_kind.groupby(['kind','sessionUserAgent']).agg({'created': 'count'})
count_session_kind.head(10)
# Out:
#                                                               created
# kind                       sessionUserAgent
# EVENT_HOMEPAGE             adjust.com                               6
# EVENT_Homepage             adjust.com                              70
# EVENT_LISTINGVIEW_FLIGHT   adjust.com                               6
# EVENT_OPEN_APP             adjust.com                              33
# EVENT_PROMO                adjust.com                               1
# Open                       HasOffers Mobile AppTracking v1.0       22
# account_summary_first_step http-kit/2.0                            13
# af_app_opened              http-kit/2.0                           428
# af_list_view               http-kit/2.0                             1
# app_open                   adjust.com                             212

# %%
count_session_kind = count_session_kind.reset_index()
count_session_kind
# Out:
#                           kind                   sessionUserAgent  created
# 0               EVENT_HOMEPAGE                         adjust.com        6
# 1               EVENT_Homepage                         adjust.com       70
# 2     EVENT_LISTINGVIEW_FLIGHT                         adjust.com        6
# 3               EVENT_OPEN_APP                         adjust.com       33
# 4                  EVENT_PROMO                         adjust.com        1
# 5                         Open  HasOffers Mobile AppTracking v1.0       22
# 6   account_summary_first_step                       http-kit/2.0       13
# 7                af_app_opened                       http-kit/2.0      428
# 8                 af_list_view                       http-kit/2.0        1
# 9                     app_open                         adjust.com      212
# 10                    deeplink                         adjust.com        5
# 11                 desconocido                            Mozilla       21
# 12                 desconocido                         adjust.com     1247
# 13                 desconocido                        desconocido       48
# 14                 desconocido                       http-kit/2.0     1231
# 15                     install                         adjust.com        1
# 16            journey drop off                         adjust.com        1
# 17      journey first drop off                         adjust.com        2
# 18            journey reserved                         adjust.com        1
# 19               login_success                       http-kit/2.0       17
# 20                        open                       http-kit/2.0       36
# 21          payment method add                         adjust.com        3
# 22               reattribution                         adjust.com        4
# 23                registration                       http-kit/2.0        3

# %% [markdown]
# Ahora utilizo un Swarnplot para visualizar los datos

# %%
plt.figure(figsize = (10,8))
sns.set_palette("dark")
cat_plot = sns.swarmplot(y = "kind", x = "created", hue = "sessionUserAgent", data = count_session_kind, size = 15)
cat_plot.set_title("Cantidad de Installs según el Tipo de Install y la Sesión de User Agent", fontsize = '20')
cat_plot.set_xlabel("Cantidad de instalaciones", fontsize = 15)
cat_plot.set_ylabel("Tipo de instalación", fontsize = 15)
# Out:
# Text(0,0.5,'Tipo de instalación')

# %%
inst.describe()
# Out:
#        application_id      ref_type      ref_hash  click_hash  \
# count     3412.000000  3.412000e+03  3.412000e+03         0.0
# mean        10.247655  1.736533e+18  4.598202e+18         NaN
# std          6.016194  1.936976e+17  2.663828e+18         NaN
# min          0.000000  1.494519e+18  4.958527e+15         NaN
# 25%          7.000000  1.494519e+18  2.268353e+18         NaN
# 50%          9.000000  1.891515e+18  4.603807e+18         NaN
# 75%         10.000000  1.891515e+18  6.912404e+18         NaN
# max         36.000000  1.891515e+18  9.218934e+18         NaN
#
#        device_countrycode  device_brand  device_model    ip_address  \
# count        3.412000e+03  1.047000e+03  3.411000e+03  3.412000e+03
# mean         4.764401e+18  1.877864e+18  4.245276e+18  4.562040e+18
# std          1.678051e+18  1.886461e+18  2.620844e+18  2.683422e+18
# min          2.970471e+18  3.083059e+17  5.112505e+16  7.118754e+15
# 25%          2.970471e+18  3.083059e+17  2.331947e+18  2.249197e+18
# 50%          6.333597e+18  2.208835e+18  2.983638e+18  4.436113e+18
# 75%          6.333597e+18  2.523246e+18  6.882415e+18  7.017564e+18
# max          6.333597e+18  9.169527e+18  9.222450e+18  9.221950e+18
#
#        device_language         hour
# count     3.378000e+03  3412.000000
# mean      4.915828e+18    13.398300
# std       2.477019e+18     7.373674
# min       1.101539e+17     0.000000
# 25%       3.301378e+18     8.000000
# 50%       3.301378e+18    15.000000
# 75%       6.977049e+18    19.000000
# max       9.028383e+18    23.000000

# %% [markdown]
# ## Veo desde qué fuente de publicidad se realizan más instalaciones

# %%
count_pub = inst['ref_type'].value_counts()
count_pub
# Out:
# 1891515180541284343    2080
# 1494519392962156891    1332
# Name: ref_type, dtype: int64

# %% [markdown]
# Sabemos que solo hay dos focos posibles, publicidad de Apple (IFA) o publicidad de Google.

# %%
plt.figure(1, figsize=(7,7))
the_grid = GridSpec(1, 1)


cmap = plt.get_cmap('Set2')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

source_pie = plt.pie(count_pub.values, labels = count_pub.index, autopct='%1.1f%%', shadow=True, colors=colors)

plt.suptitle('Installs: Fuentes de publicidad', fontsize = 20)

plt.legend()
